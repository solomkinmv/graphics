# %%
import math
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D

# %%
# %matplotlib inline
# %matplotlib notebook

# %%
radius = 10
X = np.linspace(0, radius, num=100)

# %%
X
# Out:
# array([  0.        ,   0.1010101 ,   0.2020202 ,   0.3030303 ,
#          0.4040404 ,   0.50505051,   0.60606061,   0.70707071,
#          0.80808081,   0.90909091,   1.01010101,   1.11111111,
#          1.21212121,   1.31313131,   1.41414141,   1.51515152,
#          1.61616162,   1.71717172,   1.81818182,   1.91919192,
#          2.02020202,   2.12121212,   2.22222222,   2.32323232,
#          2.42424242,   2.52525253,   2.62626263,   2.72727273,
#          2.82828283,   2.92929293,   3.03030303,   3.13131313,
#          3.23232323,   3.33333333,   3.43434343,   3.53535354,
#          3.63636364,   3.73737374,   3.83838384,   3.93939394,
#          4.04040404,   4.14141414,   4.24242424,   4.34343434,
#          4.44444444,   4.54545455,   4.64646465,   4.74747475,
#          4.84848485,   4.94949495,   5.05050505,   5.15151515,
#          5.25252525,   5.35353535,   5.45454545,   5.55555556,
#          5.65656566,   5.75757576,   5.85858586,   5.95959596,
# ...

# %%
Y = np.vectorize(lambda x: radius * radius - x * x)(X)

# %%
Y
# Out:
# array([ 100.        ,   99.98979696,   99.95918784,   99.90817264,
#          99.83675135,   99.74492399,   99.63269054,   99.50005102,
#          99.34700541,   99.17355372,   98.97969595,   98.7654321 ,
#          98.53076217,   98.27568615,   98.00020406,   97.70431589,
#          97.38802163,   97.05132129,   96.69421488,   96.31670238,
#          95.9187838 ,   95.50045914,   95.0617284 ,   94.60259157,
#          94.12304867,   93.62309968,   93.10274462,   92.56198347,
#          92.00081624,   91.41924293,   90.81726354,   90.19487807,
#          89.55208652,   88.88888889,   88.20528517,   87.50127538,
#          86.7768595 ,   86.03203755,   85.26680951,   84.48117539,
#          83.67513519,   82.84868891,   82.00183655,   81.1345781 ,
#          80.24691358,   79.33884298,   78.41036629,   77.46148352,
#          76.49219467,   75.50249974,   74.49239873,   73.46189164,
#          72.41097847,   71.33965922,   70.24793388,   69.13580247,
# ...

# %%
zHeight = 20
dotsPerLayer = 100

# %%
u = np.linspace(0, 1, num=dotsPerLayer)

# %%
x = np.cos(2 * math.pi * u)
y = np.sin(2 * math.pi * u)
z = list(map(lambda el: [el] * dotsPerLayer, np.linspace(0, 1000, num=zHeight)))

# %%
fig = plt.figure()

ax = Axes3D(fig)


ax.scatter(repeat(x, zHeight), repeat(y, zHeight), z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def repeat(np_array, n):
    return np.array([np_array] * n)

# %%
converting_matrix = np.matrix([
    [math.sqrt(3), 0, -math.sqrt(3)],
    [1, 2, 1],
    [math.sqrt(2), -math.sqrt(2), math.sqrt(2)]]);

# %%
converting_matrix
# Out:
# matrix([[ 1.73205081,  0.        , -1.73205081],
#         [ 1.        ,  2.        ,  1.        ],
#         [ 1.41421356, -1.41421356,  1.41421356]])

# %%
x
# Out:
# array([ 1.        ,  0.99798668,  0.99195481,  0.9819287 ,  0.9679487 ,
#         0.95007112,  0.92836793,  0.90292654,  0.87384938,  0.84125353,
#         0.80527026,  0.76604444,  0.72373404,  0.67850941,  0.63055267,
#         0.58005691,  0.52722547,  0.47227107,  0.41541501,  0.35688622,
#         0.29692038,  0.23575894,  0.17364818,  0.1108382 ,  0.04758192,
#        -0.01586596, -0.07924996, -0.14231484, -0.20480667, -0.26647381,
#        -0.32706796, -0.38634513, -0.44406661, -0.5       , -0.55392006,
#        -0.60560969, -0.65486073, -0.70147489, -0.74526445, -0.78605309,
#        -0.82367658, -0.85798341, -0.88883545, -0.91610846, -0.93969262,
#        -0.95949297, -0.97542979, -0.98743889, -0.99547192, -0.99949654,
#        -0.99949654, -0.99547192, -0.98743889, -0.97542979, -0.95949297,
#        -0.93969262, -0.91610846, -0.88883545, -0.85798341, -0.82367658,
#        -0.78605309, -0.74526445, -0.70147489, -0.65486073, -0.60560969,
# ...

# %%
stacked_xy = np.column_stack((x, y))

# %%
converting_matrix.dot(np.array([stacked_xy[0][0], stacked_xy[0][1], 0]))
# Out:
# matrix([[ 1.73205081,  1.        ,  1.41421356]])

# %%
xi = []
yi = []
for xy in stacked_xy:
    cm = converting_matrix.dot(np.array([xy[0], xy[1], 0]))
    print(cm)
    # xi.append(cm[0])
    # yi.append(cm[1])
# Out:
# [[ 1.73205081  1.          1.41421356]]
# [[ 1.72856363  1.12483452  1.32167133]]
# [[ 1.71811613  1.24513972  1.22380718]]
# [[ 1.70075039  1.36043119  1.1210152 ]]
# [[ 1.67653633  1.47024468  1.01370929]]
# [[ 1.64557145  1.57413801  0.90232153]]
# [[ 1.60798043  1.67169284  0.78730044]]
# [[ 1.56391464  1.76251636  0.66910916]]
# [[ 1.51355152  1.84624285  0.54822362]]
# [[ 1.45709386  1.92253517  0.42513058]]
# [[ 1.394769    1.99108612  0.30032569]]
# [[ 1.3268279   2.05161966  0.17431149]]
# [[ 1.25354413  2.10389206  0.0475954 ]]
# [[ 1.17521277  2.14769283 -0.07931235]]
# [[ 1.09214926  2.1828456  -0.20590072]]
# [[ 1.00468804  2.20920881 -0.33166001]]
# [[ 0.9131813   2.22667633 -0.45608382]]
# [[ 0.8179975   2.2351778  -0.57867114]]
# [[ 0.71951991  2.234679   -0.69892836]]
# [[ 0.61814507  2.22518194 -0.81637124]]
# [[ 0.51428118  2.20672486 -0.93052688]]
# [[ 0.40834645  2.17938207 -1.04093562]]
# [[ 0.30076747  2.14326368 -1.14715287]]
# ...

# %%
converting_matrix.dot([1, 1, 1])
# Out:
# matrix([[ 0.        ,  4.        ,  1.41421356]])

# %%
plt.scatter([1, 2], [1, 2])
# Out:
# <img src="data:image/png;base64,..." width="640">
